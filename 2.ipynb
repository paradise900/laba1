# %%
import pandas as pd

number_of_books = 20

book_records = pd.read_csv('2.csv', sep=';', )

# %%
tags = set()
names_dic = {}
for name in book_records['Publisher']:
    tags.add(name)
    names_dic[x] = 1 + names_dic.get(name, 0)
print(*tags, sep=', ')
books = []
for number, publisher in dic.items():
    books.append([publisher, number])
    
print(sorted(books, reverse=True)[:number_of_books])
# Out:
# Ullstein Buchverlage GmbH &amp; Co. KG / Ullstein Tas, Weatherhill Inc., Souvenir Press, Maverick Books, Viking Juvenile, William Morrow, Ullstein Tb, St. Martin's Press, Thomas Dunne Books, T A N Books &amp; Publishers, Pond Publishing, Jossey-Bass, Harperentertn, Marvel Books, New York Review Children's Collection, Black Sparrow Books, Transworld Publishers (Division of Random House Australia), Sourcebooks Landmark, Edizioni E/O, Springer-Verlag, Akron Art Museum, Topaz, Debate, Nelson Bibles, Authors Choice Press, Ryland Peters &amp; Small Ltd, DK Ink, Stoddart Kids, Anchor (UK), Critics Choice Paperbacks/Lorevan Publishing, 3f Publications, Minerva Press Ltd., Bloomsbury Publishing Plc, Brooking International, American Federation of Astrologers, Gulf Publishing Company, Scholastic Paperbacks (Mm), Cedar Fort. Inc, Ediciones Urano, St. Martin's Griffin, Chronicle Books, Roc, Ace Books, Fawcett, McClelland &amp; Stewart, Harcourt Childrens Books, Great Quotations, BBC, Scarborough 
# ...
