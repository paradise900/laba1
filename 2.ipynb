# %%
import pandas as pd


df = pd.read_csv('2.csv', sep=';', )

# %%
a = set()
dic = {}
for x in df['Publisher']:
    a.add(x)
    dic[x] = 1 + dic.get(x, 0)
print(*a, sep=', ')
arr = []
for i, j in dic.items():
    arr.append([j, i])
    
print(sorted(arr, reverse=True)[:20])
# Out:
# Schroeder M.V., Simon &amp; Schuster Children's Publishing, Grupo Anaya Comercial, Weatherhill Inc., Crossroad General Interest, Taylor Trade Publishing, Jossey-Bass, Hannover House USA, Intercultural Press, Editorial EmpГєries, Vintage Canada, Shelter Publications, MJF Books, Douglas &amp; McIntyre, Parkgate Books, Northlight Communications, distributed by Houghton Mifflin, Actes Sud, G. P. Putnam's Sons, Fulcrum Publishing, Celestial Arts, Scott Foresman (Pearson K-12), Palgrave-Macmillan, Rowohlt Tb., Apple Classics (Scholastic), Phoenix Press (UK), HSA Publications, Cliffs Notes, Scholastic Paperbacks (Mm), Toby Press, Longstreet Press, Weiser Books, Amereon Ltd, Reignbow, Chicken House, Loveswept, Summit Books, Cardoza, Jones &amp; Bartlett Pub, City Lights Publishers, Essence Communications, Routledge &amp; K. Paul, Prentice Hall (Sd), House of Anansi Press, St Martins Pr, 1stBooks Library, Thomas Nelson Publishers, Dorling Kindersley Publishing, North Atlantic Books, Viking Ch
# ...
